# %%
import numpy as np
import matplotlib.pyplot as plt 
# %matplotlib inline
import pandas as pd

# %%
mf=pd.read_csv("Portfolios_Formed_on_ME_monthly_EW.csv")

# %%
mf
# Out:
#       Unnamed: 0   <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  \
# 0         192607 -99.99  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47
# 1         192608 -99.99   3.90    3.04   2.09   3.84   3.59   3.71   1.61
# 2         192609 -99.99  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50
# 3         192610 -99.99  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36
# 4         192611 -99.99  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39
# ...          ...    ...    ...     ...    ...    ...    ...    ...    ...
# 1105      201808 -99.99   3.47    4.04   2.87   3.09   5.05   3.90   3.54
# 1106      201809 -99.99  -2.24   -1.85   0.08  -2.04  -2.38  -2.48  -0.74
# 1107      201810 -99.99 -10.76  -10.88  -7.63 -10.52 -11.74 -10.55  -9.45
# 1108      201811 -99.99  -2.08    2.18   2.19  -2.78   1.69   1.46   2.62
# 1109      201812 -99.99 -14.28  -12.41  -9.76 -14.77 -12.44 -12.22 -11.34
#
#       Hi 20  Lo 10  Dec 2  Dec 3  Dec 4  Dec 5  Dec 6  Dec 7  Dec 8  Dec 9  \
# ...

# %%
mf=pd.read_csv("Portfolios_Formed_on_ME_monthly_EW.csv",header=0,index_col=0)
mf
# Out:
#          <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  Lo 10  \
# 192607 -99.99  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33  -1.45
# 192608 -99.99   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33   5.12
# 192609 -99.99  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09   0.93
# 192610 -99.99  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95  -4.84
# 192611 -99.99  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16  -0.78
# ...       ...    ...     ...    ...    ...    ...    ...    ...    ...    ...
# 201808 -99.99   3.47    4.04   2.87   3.09   5.05   3.90   3.54   2.49   2.41
# 201809 -99.99  -2.24   -1.85   0.08  -2.04  -2.38  -2.48  -0.74   0.19  -1.68
# 201810 -99.99 -10.76  -10.88  -7.63 -10.52 -11.74 -10.55  -9.45  -7.41 -10.02
# 201811 -99.99  -2.08    2.18   2.19  -2.78   1.69   1.46   2.62   2.49  -3.65
# 201812 -99.99 -14.28  -12.41  -9.76 -14.77 -12.44 -12.22 -11.34  -9.21 -15.31
#
# ...

# %%
mf1=pd.read_csv("Portfolios_Formed_on_ME_monthly_EW.csv",header=0,index_col=0,parse_dates=True, na_values=-99.99)
mf1
# Out:
#         <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  Lo 10  \
# 192607   NaN  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33  -1.45
# 192608   NaN   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33   5.12
# 192609   NaN  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09   0.93
# 192610   NaN  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95  -4.84
# 192611   NaN  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16  -0.78
# ...      ...    ...     ...    ...    ...    ...    ...    ...    ...    ...
# 201808   NaN   3.47    4.04   2.87   3.09   5.05   3.90   3.54   2.49   2.41
# 201809   NaN  -2.24   -1.85   0.08  -2.04  -2.38  -2.48  -0.74   0.19  -1.68
# 201810   NaN -10.76  -10.88  -7.63 -10.52 -11.74 -10.55  -9.45  -7.41 -10.02
# 201811   NaN  -2.08    2.18   2.19  -2.78   1.69   1.46   2.62   2.49  -3.65
# 201812   NaN -14.28  -12.41  -9.76 -14.77 -12.44 -12.22 -11.34  -9.21 -15.31
#
# ...

# %%
mf1.head()
# Out:
#         <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  Lo 10  \
# 192607   NaN  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33  -1.45
# 192608   NaN   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33   5.12
# 192609   NaN  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09   0.93
# 192610   NaN  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95  -4.84
# 192611   NaN  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16  -0.78
#
#         Dec 2  Dec 3  Dec 4  Dec 5  Dec 6  Dec 7  Dec 8  Dec 9  Hi 10
# 192607   0.29  -0.15   1.33   1.24   1.98   1.55   1.38   3.38   3.29
# 192608   2.59   4.03   3.15   2.72   4.72   1.60   1.63   0.98   3.70
# 192609  -1.87  -2.27  -0.53   0.07  -0.07  -1.64   0.64  -0.86   0.67
# 192610  -1.77  -3.36  -4.83  -2.98  -2.80  -3.45  -3.27  -3.47  -2.43
# 192611  -0.32  -0.29   4.65   3.24   3.57   3.82   2.95   3.61   2.70

# %%
#lets look at small cap and large cap companies
returns=mf1[['Lo 10','Hi 10']]
returns.columns=['SmallCap','LargeCap']
returns.head()
# Out:
#         SmallCap  LargeCap
# 192607     -1.45      3.29
# 192608      5.12      3.70
# 192609      0.93      0.67
# 192610     -4.84     -2.43
# 192611     -0.78      2.70

# %%
returns=returns/100
returns.head()
# Out:
#         SmallCap  LargeCap
# 192607   -0.0145    0.0329
# 192608    0.0512    0.0370
# 192609    0.0093    0.0067
# 192610   -0.0484   -0.0243
# 192611   -0.0078    0.0270

# %%
returns.index = pd.to_datetime(returns.index, format="%Y%m")
returns.index = returns.index.to_period('M')
returns.head()
# Out:
#          SmallCap  LargeCap
# 1926-07   -0.0145    0.0329
# 1926-08    0.0512    0.0370
# 1926-09    0.0093    0.0067
# 1926-10   -0.0484   -0.0243
# 1926-11   -0.0078    0.0270

# %%
returns.plot()

# %%
returns['1960']
# Out:
#          SmallCap  LargeCap
# 1960-01    0.0077   -0.0700
# 1960-02   -0.0141    0.0097
# 1960-03   -0.0200   -0.0135
# 1960-04   -0.0358   -0.0133
# 1960-05   -0.0050    0.0415
# 1960-06    0.0226    0.0224
# 1960-07   -0.0079   -0.0293
# 1960-08    0.0589    0.0269
# 1960-09   -0.0656   -0.0579
# 1960-10   -0.0351    0.0018
# 1960-11    0.0179    0.0499
# 1960-12    0.0178    0.0463

# %%
returns['1960'].plot()

# %%
wealth_index=1000*(1+returns['LargeCap']).cumprod()

# %%
wealth_index.plot()

# %%
wealth_index2=2000*(1+returns['LargeCap']).cumprod()

# %%
wealth_index.plot()
wealth_index2.plot()

# %%
previous_peak=wealth_index.cummax()
previous_peak.plot(color='red')

# %%
drawdown=(wealth_index-previous_peak)/previous_peak
drawdown.plot(color='teal')

# %%
print(drawdown.min())
print(drawdown.idxmin())
# Out:
# -0.8400375277943123
# 1932-05

# %%
wealth_index.plot(color='teal')
previous_peak.plot(color='red')
